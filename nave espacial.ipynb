# %%
print("iniciando a exploraçao")
conquistas = 0
explorando = True
    
while explorando :
    obstaculo = input ("ha obstaculos (s/n): ")
    
    if obstaculo == "S" or "s":
        print("montanha a frente")
        
        escolha = input("Deseja (1) Escalar ou (2) Contornar? ")

        if escolha == "1":
            sucesso = input("A escalada foi bem-sucedida? (s/n): ")
        
        if sucesso == "s" or "S":
            print(" Escalada realizada com sucesso!")
            break
        else:
            print(" Falha na escalada! Tente novamente.")
            escolha = input("Deseja (1) Escalar ou (2) Contornar? ")
        
        if escolha == "2":
            print(" Montanha contornada com sucesso!")
            break
        else:
            print("Opção inválida. Escolha 1 ou 2.")
